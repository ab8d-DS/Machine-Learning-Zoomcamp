# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Q1: Pandas Version

# %%
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# ### Loading the Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv')

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %% [markdown]
# ### Q2: Records Count

# %%
# How many records are in the dataset?
print(f"Number of records in the dataset: {df.shape[0]}")
# Out:
# Number of records in the dataset: 10000

# %% [markdown]
# ### Q3: fuel Types

# %%
# How many fuel types are presented in the dataset?
print(f"Number of fuel types represented in the data: {df['fuel_type'].nunique()}")
# Out:
# Number of fuel types represented in the data: 3

# %% [markdown]
# ### Q4: Missing Values

# %%
# How many columns in the dataset have missing values?
print(f'Number of columns that have missing values: {len(df.isna().sum()[df.isna().sum() > 0])}')
# Out:
# Number of columns that have missing values: 2

# %% [markdown]
# ### Q5: Max fuel efficiency

# %%
# What's the maximum fuel efficiency of cars from Asia?
print(f"the maximum fuel efficiency of cars from Asia: {df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()}")
# Out:
# the maximum fuel efficiency of cars from Asia: 41.2

# %% [markdown]
# ### Q6: Median value of horsepower

# %%
#1: Find the median value of the horsepower column in the dataset.
median_before = df['horsepower'].median()
print(f"median value of the horsepower: {df['horsepower'].median()}")

#2: Next, calculate the most frequent value of the same horsepower column.
most_frequent = df['horsepower'].mode()[0]
print(f"most frequent value: {most_frequent}")

#3: Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
df['horsepower'] = df['horsepower'].fillna(most_frequent)

#4: Now, calculate the median value of horsepower once again.
median_after = df['horsepower'].median()
print(f'median value of the horsepower after fill the missing values: {df['horsepower'].median()}')
print(f"Has it changed? {(median_after - median_before) != 0}")
# Out:
# median value of the horsepower: 254.0
# most frequent value: 252.0
# median value of the horsepower after fill the missing values: 252.0
# Has it changed? True

# %% [markdown]
# ### Q7: Sum of weights

# %%
#1: Select all the cars from Asia
#2: Select only columns vehicle_weight and model_year
#3: Select the first 7 values
#4: Get the underlying NumPy array. Let's call it X
X = df[df['origin'] == 'Asia'][['vehicle_weight','model_year']].head(7).values

#5: Compute matrix-matrix multiplication between the transpose of X and X. Let's call the result XTX
XTX = X.T.dot(X)

#6: invert XTX
XTX_inv = np.linalg.inv(XTX)

#7: Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200]
y = [1100, 1300, 800, 900, 1000, 1100, 1200]

#8: Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
w = (XTX_inv.dot(X.T)).dot(y)

#9: What's the sum of all the elements of the result?
print(f"The sum of all the elements of the results: {w.sum().round(3)}")
# Out:
# The sum of all the elements of the results: 0.369
